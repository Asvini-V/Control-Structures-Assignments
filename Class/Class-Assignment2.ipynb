# %%
from classfile import MultiFunction

MultiFunction.Eligible()
# Out:
# Your Gender:Male
# Your Age:20
# 'NOT ELIGIBLE'

# %%
MultiFunction.Subfields()
# Out:
# Subfields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
MultiFunction.percentage()
# Out:
# Subject1:45
# Subject2:56
# Subject3:76
# Subject4:74
# Subject5:80
# Total: 331
# Percentage: 66.2

# %%
MultiFunction.triangle()
# Out:
# Height:4
# Breadth:5
# Area formula: (Height*Breadth)/2
# Area of Triangle: 10.0
# Height1:4
# Height2:5
# Breadth:50
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 59
# (10.0, 59)

# %%
MultiFunction.OddEven()
# Out:
# Enter a number:57
# 57 is Odd number
