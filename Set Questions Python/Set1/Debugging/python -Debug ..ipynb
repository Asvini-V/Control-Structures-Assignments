# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
# SOLUTION: Removed extra space before 'for'
#           Added missing colon : at the end of the for statement


for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
# SOLUTION:  cannot add string and integer, istead rewrite as
#            print(a + int(b))  -----  if the intention is to add numbers
#            print(str(a) + b)  -----  if the intention is to join texts

a = 10
b = "5"
print(a + int(b))
print(str(a) + b)
# Out:
# 15
# 105

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
# SOLUTION: Removed extra space before 'def'
#           Added missing colon : after the function definition
#           Added a function call to display the result


def add_numbers(a, b):
    return a + b
add_numbers(5,6)
# Out:
# 11

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
# SOLUTION: Removed extra space before numbers =
#           Fixed index: last element is at 3 (Python lists are 0-indexed)


numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
# SOLUTION: Parentheses were missing. Added () to print.

print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
# SOLUTION: A number cannot be divided by zero; changed denominator to a non-zero value

x=5/10

# %%
#7.Find the error in the following Python code:

name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
# SOLUTION: Cannot concatenate a string with a number; converted age to string using str()

name = "Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
# SOLUTION: Step -1 goes backward, but start < stop, so loop never runs.
#           Fix : either change step to 1 or change start and stop to 10, 1 to count backward

for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
# SOLUTION: = is assignment operator; ==  is used for comparison in if statements

x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
# SOLUTION: Missing colon : after function definition
#           Added function call to execute the function


def greet(name):
    print("Hello, " + name)
    
greet(name)
# Out:
# Hello, Alice
